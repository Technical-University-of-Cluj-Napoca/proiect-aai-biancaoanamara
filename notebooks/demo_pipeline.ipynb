# %% [markdown]
# # Demo Pipeline for Agentic AI Code Review
#
# This notebook demonstrates the end-to-end functionality of the Agentic AI Code Review and Security Vulnerability Detection System.

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from src.graph.workflow import create_workflow
from dotenv import load_dotenv

load_dotenv()

# %%
# Initialize graph
workflow = create_workflow()

initial_state = {
    "repo_url": "https://github.com/vulnerables/web-dvwa", # Example repo
    "repo_path": "",
    "repository": None,
    "reviews": [],
    "final_report": ""
}

# %%
# Run the graph
print("Running workflow...")
final_state = workflow.invoke(initial_state)
print("Workflow finished!")

# %%
# Print final report
print(final_state["final_report"])
